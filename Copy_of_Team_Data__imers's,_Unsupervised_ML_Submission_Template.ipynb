# %% [markdown]
# <a href="https://colab.research.google.com/github/reenaverma97/Netflix-movies-and-TV-shows-clustering/blob/main/Copy_of_Team_Data__imers's%2C_Unsupervised_ML_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Netflix movies and TV shows clustering**

# %% [markdown]
# ##### **Project Type**    - **Unsupervised ML**
# ##### **Contribution**    - **Team**
# ##### **Team Member 1 - Md Kamran**
# ##### **Team Member 2 - Reena Verma**
# ##### **Team Member 3** - **Mithin barde**
# ##### **Team Member 4** - **Krunal sonare**
# ##### **Team Member 5** - **Rishabh Gupta**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This dataset consists of tv shows and movies available on Netflix as of 2019. The dataset is collected from Flixable which is a third-party Netflix search engine.
#
# In 2018, they released an interesting report which shows that the number of TV shows on Netflix has nearly tripled since 2010. The streaming service’s number of movies has decreased by more than 2,000 titles since 2010, while its number of TV shows has nearly tripled. It will be interesting to explore what all other insights can be obtained from the same dataset.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# GitHub Link -https://github.com/reenaverma97

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This dataset consists of tv shows and movies available on Netflix as of 2019. The dataset is collected from Flixable which is a third-party Netflix search engine.
#
# In 2018, they released an interesting report which shows that the number of TV shows on Netflix has nearly tripled since 2010. The streaming service’s number of movies has decreased by more than 2,000 titles since 2010, while its number of TV shows has nearly tripled. It will be interesting to explore what all other insights can be obtained from the same dataset.
#
# Integrating this dataset with other external datasets such as IMDB ratings, rotten tomatoes can also provide many interesting findings.
#
# **In this project, we are required to do**
#
#
#
# 1.   Exploratory Data Analysis.
# 2.   Understanding what type content is available in different countries.
# 3.  Is Netflix has increasingly focusing on TV rather than movies in recent years.
# 4.   Clustering similar content by matching text-based features.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# ### **Importing the Libraries**

# %%
# Importing Libraries
import numpy as np
import pandas as pd
from numpy import math
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.pyplot import figure
import plotly.graph_objects as go
import plotly.offline as py
import plotly.express as px
from datetime import datetime

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### **Mounting the drive and importing the dataset**

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing the dtaset
dataSet = pd.read_csv('/content/drive/MyDrive/unsupervised ML/NETFLIX MOVIES AND TV SHOWS CLUSTERING.csv')

# %% [markdown]
# ### **Dataset First Look**

# %%
# Dataset First Look
dataSet.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
# Checking last five rows
dataSet.tail()
# Out:
#      show_id     type                                    title     director  \
# 7782   s7783    Movie                                     Zozo  Josef Fares
# 7783   s7784    Movie                                   Zubaan  Mozez Singh
# 7784   s7785    Movie                        Zulu Man in Japan          NaN
# 7785   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    cast  \
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                                            Nasty C
# 7785                         Adriano Zumbo, Rachel Khoo
# 7786                                                NaN
#
#                                                 country          date_added  \
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %% [markdown]
# ### **Dataset Rows & Columns count, name**

# %%
# Checking the shape of dataset
dataSet.shape
# Out:
# (7787, 12)

# %%
# Checking columns
dataSet.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# There are 12 columns

# %% [markdown]
# ### **Collecting Dataset Information**

# %%
# Dataset Info
dataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %% [markdown]
# #### **Duplicate Values Checking**

# %%
# Dataset Duplicate Value Count
dataSet[dataSet.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# There are no duplicate values.

# %% [markdown]
# #### **Cheking for Null Values count**

# %%
# Checking Null Values
dataSet.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
# Total Null Values Count
dataSet.isnull().sum().sum()
# Out:
# 3631

# %%
# Visualizing the missing values
msno.bar(dataSet)
plt.show()

# %% [markdown]
# There are 3631 null values in the dataset, 2389 null values in director column, 718 null values in cast column ,507 null values in country column ,10 in date_added and 7 in rating. so we need to handle the null values

# %% [markdown]
# ### **Details About The Dataset!**

# %% [markdown]
# Here we see the dataset has 7787 rows and 12 columns, there are no duplicate values but this dataset has 3631 null values of which 2389 null values in director column, 718 null values in cast column ,507 null values in country column ,10 in date_added and 7 in rating. So here we need to handle with the null values.

# %%
# Handling Null Values
dataSet['cast'].fillna(value='No cast',inplace=True)
dataSet['country'].fillna(value=dataSet['country'].mode()[0],inplace=True)

# %%
# Dropping varialbles
#'date_added' and 'rating' contains an insignificant portion of the data so we will drop them from the dataset
dataSet.dropna(subset=['date_added','rating'],inplace=True)

# %%
# Dropping Director column
dataSet.drop(['director'],axis=1,inplace=True)

# %%
# Checking the Null Values again !
dataSet.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# So as we see, now there are no Null values.

# %% [markdown]
# ## ***Understanding The Variables***

# %%
# Dataset Describe
dataSet.describe(include='all')
# Out:
#        show_id   type title     cast        country       date_added  \
# count     7770   7770  7770     7770           7770             7770
# unique    7770      2  7770     6818            681             1563
# top         s1  Movie    3%  No cast  United States  January 1, 2020
# freq         1   5372     1      718           3051              118
# mean       NaN    NaN   NaN      NaN            NaN              NaN
# std        NaN    NaN   NaN      NaN            NaN              NaN
# min        NaN    NaN   NaN      NaN            NaN              NaN
# 25%        NaN    NaN   NaN      NaN            NaN              NaN
# 50%        NaN    NaN   NaN      NaN            NaN              NaN
# 75%        NaN    NaN   NaN      NaN            NaN              NaN
# max        NaN    NaN   NaN      NaN            NaN              NaN
#
#         release_year rating  duration      listed_in  \
# count    7770.000000   7770      7770           7770
# ...

# %%
# Dataset Columns
dataSet.columns
# Out:
# Index(['show_id', 'type', 'title', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ### **Variables or Dataset Description**

# %% [markdown]
# ![Unsupervised_ML_Netflix_Movies_and_TV_Shows_Clustering_ce34d02ec9.png](data:image/png;base64,...)

# %% [markdown]
# ### **Check Unique Values for each variable.**

# %%
# Check Unique Values for each variable.
for i in dataSet.columns.tolist():
  print("No. of unique values in ",i,"is",dataSet[i].nunique(),".")
# Out:
# No. of unique values in  show_id is 7770 .
# No. of unique values in  type is 2 .
# No. of unique values in  title is 7770 .
# No. of unique values in  cast is 6818 .
# No. of unique values in  country is 681 .
# No. of unique values in  date_added is 1563 .
# No. of unique values in  release_year is 73 .
# No. of unique values in  rating is 14 .
# No. of unique values in  duration is 216 .
# No. of unique values in  listed_in is 491 .
# No. of unique values in  description is 7752 .

# %% [markdown]
# ## ***Exploratory Data Analysis***

# %% [markdown]
# ### **Checking the numbers of Netflix's Movies and TV shows available in this dataset.**

# %%
dataSet['type'].value_counts()
# Out:
# Movie      5372
# TV Show    2398
# Name: type, dtype: int64

# %%
sns.countplot(dataSet['type'])

# %% [markdown]
# This data set has 5372 movies and 2398 TV shows, which means there are more numbers of movies available on Netflix than TV shows according to this data set.

# %%
# Rating Checking
dataSet['rating']
# Out:
# 0       TV-MA
# 1       TV-MA
# 2           R
# 3       PG-13
# 4       PG-13
#         ...
# 7782    TV-MA
# 7783    TV-14
# 7784    TV-MA
# 7785    TV-PG
# 7786    TV-MA
# Name: rating, Length: 7770, dtype: object

# %%
# Assigning the ratings into grouped categories
ratings = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
}
dataSet['target_ages'] = dataSet['rating'].replace(ratings)

# %%
# The type should be a category
dataSet['type'] = pd.Categorical(dataSet['type'])

# %%
# Target set is another category (4 classes)
dataSet['target_ages'] = pd.Categorical(dataSet['target_ages'], categories=['Kids','Older Kids','Teens','Adults'])

# %%
# Printig the Data
dataSet
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                                    cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
# Creating two extra columns in the name of Movies and TV shows
tv_shows = dataSet[dataSet['type']=='TV Show']
movies = dataSet[dataSet['type']=='Movie']

# %% [markdown]
# ### **Rating check age group wise**

# %%
# Rating based on rating system of all TV Shows
tv_ratings = tv_shows.groupby(['rating'])['show_id'].count().reset_index(name='count').sort_values(by='count',ascending=False)
fig_dims = (14,7)
fig, ax = plt.subplots(figsize=fig_dims)  
sns.pointplot(x='rating',y='count',data=tv_ratings)
plt.title('TV Show Ratings',size='20')
plt.show()

# %%
# Movies Ratings based on Target age groups
plt.figure(figsize=(14,6))
plt.title('movie ratings')
sns.countplot(x=movies['rating'],hue=movies['target_ages'],data=movies,order=movies['rating'].value_counts().index)

# %% [markdown]
# ### **Collecting Information About Netflix Movies & TV Shows**

# %%
# Information about Movies.
movies_year =movies['release_year'].value_counts().sort_index(ascending=False)

# %%
# Print number of Movies Release per Year.
print(movies_year)
# Out:
# 2021     12
# 2020    411
# 2019    582
# 2018    734
# 2017    742
#        ...
# 1946      1
# 1945      3
# 1944      3
# 1943      3
# 1942      2
# Name: release_year, Length: 72, dtype: int64

# %%
# Production Growth yearly basis
sns.set(font_scale=1.4)
movies_year.plot(figsize=(12, 8), linewidth=2.5, color='maroon',label="Movies / year",ms=3)
plt.xlabel("Years", labelpad=15)
plt.ylabel("Number", labelpad=15)
plt.title("Production growth yearly", y=1.02, fontsize=22);

# %%
# Analysing how many movies released per year in last 15 years
plt.figure(figsize=(15,5))
sns.countplot(y=movies['release_year'],data=dataSet,order=movies['release_year'].value_counts().index[0:20])

# %%
# Information about TV Shows.
tvshows_year =tv_shows['release_year'].value_counts().sort_index(ascending=False)

# %%
# Print number of TV Shows Release per Year.
print(tvshows_year)
# Out:
# 2021     19
# 2020    457
# 2019    414
# 2018    386
# 2017    268
# 2016    239
# 2015    156
# 2014     90
# 2013     63
# 2012     60
# 2011     39
# 2010     36
# 2009     34
# 2008     22
# 2007     13
# 2006     13
# 2005     12
# 2004      9
# 2003      7
# 2002      6
# 2001      4
# 2000      4
# 1999      7
# 1998      4
# 1997      4
# 1996      3
# 1995      2
# 1994      1
# 1993      4
# 1992      2
# 1991      1
# 1990      3
# 1989      1
# 1988      2
# 1986      2
# 1985      1
# 1981      1
# 1979      1
# 1977      1
# 1974      1
# 1972      1
# 1968      1
# 1967      1
# 1963      1
# 1946      1
# 1925      1
# Name: release_year, dtype: int64

# %%
# Production Growth yearly basis
sns.set(font_scale=1.4)
tvshows_year.plot(figsize=(12, 8), linewidth=2.5, color='blue',label="TV Shows / year")
plt.xlabel("Years", labelpad=15)
plt.ylabel("Number", labelpad=15)
plt.title("Production growth yearly", y=1.02, fontsize=22);

# %%
# Analysing how many TV Shows released per year in last 15 years.
plt.figure(figsize=(15,5))
sns.countplot(y=tv_shows['release_year'],data=dataSet,order=tv_shows['release_year'].value_counts().index[0:20])

# %% [markdown]
# ### **Comparing The Yealry Production Growth Rate Between Netflix Movies & TV Shows**

# %%
# Comparison Between Movies & TV Shows
sns.set(font_scale=1.4)
movies_year.plot(figsize=(12, 8), linewidth=2.5, color='maroon',label="Movies / year",ms=3)
tvshows_year.plot(figsize=(12, 8), linewidth=2.5, color='blue',label="TV Shows / year")
plt.xlabel("Years", labelpad=15)
plt.ylabel("Number", labelpad=15)
plt.title("Production growth yearly", y=1.02, fontsize=22);

# %% [markdown]
# The number of available movies on Netflix is growing significantly faster than the number of TV shows.
#
# In both 2018 and 2019, approximately 1200 new movies were added.
#
# We saw a huge increase in the number of movies and television episodes after 2014.
#
# But there is a significant drop in the number of movies and television episodes produced after 2019 because of the Covid-19 situation.
#
# It appears that Netflix has focused more attention on increasing Movie content than TV Shows. Movies have increased much more dramatically than TV shows.

# %%
# Printing the Data
dataSet
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                                    cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
# Adding some column of month and year of addition
dataSet['month'] = pd.DatetimeIndex(dataSet['date_added']).month
dataSet.head()
# Out:
#   show_id     type  title                                               cast  \
# 0      s1  TV Show     3%  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1      s2    Movie   7:19  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2      s3    Movie  23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3      s4    Movie      9  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4      s5    Movie     21  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#
#          country         date_added  release_year rating   duration  \
# 0         Brazil    August 14, 2020          2020  TV-MA  4 Seasons
# 1         Mexico  December 23, 2016          2016  TV-MA     93 min
# 2      Singapore  December 20, 2018          2011      R     78 min
# 3  United States  November 16, 2017          2009  PG-13     80 min
# 4  United States    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# ...

# %%
# Ploting the Countplot on Monthly basis
plt.figure(figsize=(12,10))
ax=sns.countplot('month',data= dataSet)

# %%
fig, ax = plt.subplots(figsize=(15,6))

sns.countplot(x='month', hue='type',lw=5, data=dataSet, ax=ax)

# %% [markdown]
# According to the above graph as we see the most numbers of content are added to Netflix in the month of January & December.

# %%
# Analysing Top 10 Genre of the Movies
plt.figure(figsize=(14,6))
plt.title('Top10 Genre of Movies',fontweight='bold')
sns.countplot(y=tv_shows['listed_in'],data=tv_shows,order=tv_shows['listed_in'].value_counts().index[0:10],palette="viridis")

# %%
# Checking the distribution of Movie Durations
plt.figure(figsize=(10,7))
sns.distplot(movies['duration'].str.extract('(\d+)'),kde=False, color=['blue'])
plt.title('Distplot with Normal distribution for Movies',fontweight="bold")
plt.show()

# %%
# Checking the distribution of TV Shows Durations
plt.figure(figsize=(30,6))
plt.title("Distribution of TV Shows duration",fontweight='bold')
sns.countplot(x=tv_shows['duration'],data=tv_shows,order = tv_shows['duration'].value_counts().index)

# %%
# Analysing Top 20 Countries with Most Content 
plt.figure(figsize=(18,5))
sns.countplot(x=dataSet['country'],palette="magma",order=dataSet['country'].value_counts().index[0:20],hue=dataSet['type'])
plt.xticks(rotation=75)
plt.title('Top 20 countries with most contents', fontsize=20, fontweight='bold')
plt.show()

# %% [markdown]
# The above graph shows the Top 20 countries with the most content created in which we see that the United States, India, and the United Kingdom are sitting in the Top 3 spots.

# %%
# Analysing the popularity of Netflix in the World
country=dataSet['country'].value_counts().reset_index()

# Printing
country
# Out:
#                                                  index  country
# 0                                        United States     3051
# 1                                                India      923
# 2                                       United Kingdom      396
# 3                                                Japan      224
# 4                                          South Korea      183
# ..                                                 ...      ...
# 676                       Russia, United States, China        1
# 677                Italy, Switzerland, France, Germany        1
# 678              United States, United Kingdom, Canada        1
# 679               United States, United Kingdom, Japan        1
# 680  Sweden, Czech Republic, United Kingdom, Denmar...        1
#
# [681 rows x 2 columns]

# %%
# Preparing the data fot Heatmap 
dataSet['count'] = 1
data = dataSet.groupby('country')[['country','count']].sum().sort_values(by='count',ascending=False).reset_index()[:10]
data = data['country']


df_heatmap = dataSet.loc[dataSet['country'].isin(data)]
df_heatmap = pd.crosstab(df_heatmap['country'],df_heatmap['target_ages'],normalize = "index").T
df_heatmap
# Out:
# country        Canada     Egypt    France     India     Japan  Mexico  \
# target_ages
# Kids         0.180791  0.000000  0.095652  0.016251  0.008929    0.02
# Older Kids   0.225989  0.039604  0.060870  0.160347  0.272321    0.07
# Teens        0.146893  0.683168  0.165217  0.567714  0.352679    0.14
# Adults       0.446328  0.277228  0.678261  0.255688  0.366071    0.77
#
# country      South Korea     Spain  United Kingdom  United States
# target_ages
# Kids            0.027322  0.022388        0.093434       0.089479
# Older Kids      0.120219  0.044776        0.204545       0.195346
# Teens           0.382514  0.097015        0.189394       0.243199
# Adults          0.469945  0.835821        0.512626       0.471976

# %%
# Now Ploting the Heatmap
fig, ax = plt.subplots(1, 1, figsize=(12, 12))
country_order2 = ['United States', 'India', 'United Kingdom', 'Canada', 'Japan', 'France', 'South Korea', 'Spain',
       'Mexico']
age_order = ['Adults', 'Teens', 'Older Kids', 'Kids']
sns.heatmap(df_heatmap.loc[age_order,country_order2],cmap="YlGnBu",square=True, linewidth=2.5,cbar=False,
            annot=True,fmt='1.0%',vmax=.6,vmin=0.05,ax=ax,annot_kws={"fontsize":12})
plt.show()

# %% [markdown]
# The target ages for Netflix is diffrent into the diffrent countries.
#
# As we see The Netflex target ages for Us and UK are closely aligned, but in India Teen are more active than Adults in Netflex content.
#
# Also, France, Mexico, and Spain have similar content on Netflix for different age groups but in Japan and South Korea, the contents target ages is a slight difference.

# %%
# Adding some extra columns
dataSet['date_added'] = pd.to_datetime(dataSet['date_added'])
dataSet['year_added'] = dataSet['date_added'].dt.year

# printing
dataSet
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                                    cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
# All the movies and TV shows in different dataframe
movies = dataSet[dataSet['type']=='Movie']
tv_shows= dataSet[dataSet['type']=='TV Show']

# %%
# Prepearing dataframe
movies['originals'] = np.where(movies['release_year']==movies['year_added'], 'Yes', 'No')

# pie plot showing percentage of originals and others in movies
fig, ax = plt.subplots(figsize=(5,5),facecolor="#363336")
ax.patch.set_facecolor('#363336')
explode = (0, 0.1)
ax.pie(movies['originals'].value_counts(), explode=explode, autopct='%.2f%%', labels= ['Others', 'Originals'],
       shadow=True, startangle=90,textprops={'color':"black", 'fontsize': 20}, colors =['red','#F5E9F5'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f61ae2f8ee0>,
# ...
#  [Text(-0.8900699117813855, -0.6463555926434588, 'Others'),
#   Text(0.9709853583069661, 0.7051151919746822, 'Originals')],
#  [Text(-0.48549267915348293, -0.3525575959873411, '69.99%'),
#   Text(0.5664081256790635, 0.4113171953185646, '30.01%')])

# %% [markdown]
# As the above pie chart shows that 70% of movies are added on Netflix were released earlier by different modes but only 30% of movies are released on Netflix directly.

# %% [markdown]
# ## ***Applying Some Hypothesis Testing***

# %% [markdown]
# **HO: Netflix has more Movies than TV Shows.**
#
# **H1: Netflix have not more Movies than TV Shows.**

# %%
# Printing DataSet
dataSet['type'].value_counts()
# Out:
# Movie      5372
# TV Show    2398
# Name: type, dtype: int64

# %%
# Printing Movies
movies
# Out:
#      show_id   type                                    title  \
# 1         s2  Movie                                     7:19
# 2         s3  Movie                                    23:59
# 3         s4  Movie                                        9
# 4         s5  Movie                                       21
# 6         s7  Movie                                      122
# ...      ...    ...                                      ...
# 7781   s7782  Movie                                     Zoom
# 7782   s7783  Movie                                     Zozo
# 7783   s7784  Movie                                   Zubaan
# 7784   s7785  Movie                        Zulu Man in Japan
# 7786   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# ...

# %%
# Creating some extra columns
tv_shows=dataSet[dataSet['type']=='TV Show']
movies=dataSet[dataSet['type']=='Movie']

# %%
np.mean(movies)
# Out:
# release_year    2012.918280
# month              6.714073
# count              1.000000
# year_added      2018.481571
# dtype: float64

# %%
# Printing Movie Duration
movies.duration
# Out:
# 1        93 min
# 2        78 min
# 3        80 min
# 4       123 min
# 6        95 min
#          ...
# 7781     88 min
# 7782     99 min
# 7783    111 min
# 7784     44 min
# 7786     90 min
# Name: duration, Length: 5372, dtype: object

# %%
# Making copy of data frame
_hypothesis=dataSet.copy()

#head of df_hypothesis
_hypothesis.head()
# Out:
#   show_id     type  title                                               cast  \
# 0      s1  TV Show     3%  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1      s2    Movie   7:19  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2      s3    Movie  23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3      s4    Movie      9  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4      s5    Movie     21  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#
#          country date_added  release_year rating   duration  \
# 0         Brazil 2020-08-14          2020  TV-MA  4 Seasons
# 1         Mexico 2016-12-23          2016  TV-MA     93 min
# 2      Singapore 2018-12-20          2011      R     78 min
# 3  United States 2017-11-16          2009  PG-13     80 min
# 4  United States 2020-01-01          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# ...

# %%
# Filtering Movies from Type_of_show column
_hypothesis = _hypothesis[_hypothesis["type"] == "Movie"]

# %%
# With respect to each ratings assigning it into a group of categories.              
ratings_ages = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
}

_hypothesis['target_ages'] = _hypothesis['rating'].replace(ratings_ages)

# Now let's see the unique target ages 
_hypothesis['target_ages'].unique()
# Out:
# array(['Adults', 'Teens', 'Older Kids', 'Kids'], dtype=object)

# %%
# Another category is target_ages (4 classes).
_hypothesis['target_ages'] = pd.Categorical(_hypothesis['target_ages'], categories=['Kids', 'Older Kids', 'Teens', 'Adults'])

# From duration feature extracting string part and after extracting Changing the object type to numeric
_hypothesis['duration']= _hypothesis['duration'].str.extract('(\d+)')
_hypothesis['duration'] = pd.to_numeric(_hypothesis['duration'])

# Now printing head of _hypothesis
_hypothesis.head(3)
# Out:
#   show_id   type  title                                               cast  \
# 1      s2  Movie   7:19  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2      s3  Movie  23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3      s4  Movie      9  Elijah Wood, John C. Reilly, Jennifer Connelly...
#
#          country date_added  release_year rating  duration  \
# 1         Mexico 2016-12-23          2016  TV-MA        93
# 2      Singapore 2018-12-20          2011      R        78
# 3  United States 2017-11-16          2009  PG-13        80
#
#                                            listed_in  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          description target_ages  month  \
# 1  After a devastating earthquake hits Mexico Cit...      Adults     12
# ...

# %%
# Checking group_by duration and target_ages              
group_by_= _hypothesis[['duration','target_ages']].groupby(by='target_ages')

# mean of group_by variable
group=group_by_.mean().reset_index()
group
# Out:
#   target_ages    duration
# 0        Kids   66.486891
# 1  Older Kids   92.024648
# 2       Teens  110.025332
# 3      Adults   98.275145

# %%
# Creating groups In A and B variable grouping values 
A = group_by_.get_group('Kids')
B = group_by_.get_group('Older Kids')

# mean and std. calutation for kids and older kids variables
M1 = A.mean()
S1 = A.std()

M2= B.mean()
S2 = B.std()

print('Mean for movies rated for Kids {} \n Mean for  movies rated for older kids {}'.format(M1,M2))
print('Std for  movies rated for Older Kids {} \n Std for  movies rated for kids {}'.format(S2,S1))
# Out:
# Mean for movies rated for Kids duration    66.486891
# dtype: float64
#  Mean for  movies rated for older kids duration    92.024648
# dtype: float64
# Std for  movies rated for Older Kids duration    31.182577
# dtype: float64
#  Std for  movies rated for kids duration    31.739465
# dtype: float64

# %%
# Checking Null Hypothesis
from scipy.stats import ttest_ind
ttest,pval = ttest_ind(M1, M2)
print(pval)
if pval<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# nan
# accept null hypothesis

# %%
# Importing Stats
from scipy import stats

#length of groups and DOF
n1 = len(A)
n2= len(B)
print(n1,n2)

dof = n1+n2-2
print('dof',dof)

sp_2 = ((n2-1)*S1**2  + (n1-1)*S2**2) / dof
print('SP_2 =',sp_2)

sp = np.sqrt(sp_2)
print('SP',sp)

#tvalue
t_val = (M1-M2)/(sp * np.sqrt(1/n1 + 1/n2))
print('tvalue',t_val[0])
# Out:
# 267 852
# dof 1117
# SP_2 = duration    999.049147
# dtype: float64
# SP duration    31.607739
# dtype: float64
# tvalue -11.51992627853396

# %%
# Checking t-distribution
stats.t.ppf(0.025,dof)
# Out:
# -1.9620900365868952

# %%
#t-distribution
stats.t.ppf(0.975,dof)
# Out:
# 1.9620900365868947

# %% [markdown]
# Because the t-value is not in the range, the null hypothesis is rejected.
#
# As a result, movies rated for kids and older kids are not at least two hours long.

# %%
# Again Making copy of data frame
_hypothesis=dataSet.copy()

#head of df_hypothesis
_hypothesis.head()
# Out:
#   show_id     type  title                                               cast  \
# 0      s1  TV Show     3%  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1      s2    Movie   7:19  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2      s3    Movie  23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3      s4    Movie      9  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4      s5    Movie     21  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#
#          country date_added  release_year rating   duration  \
# 0         Brazil 2020-08-14          2020  TV-MA  4 Seasons
# 1         Mexico 2016-12-23          2016  TV-MA     93 min
# 2      Singapore 2018-12-20          2011      R     78 min
# 3  United States 2017-11-16          2009  PG-13     80 min
# 4  United States 2020-01-01          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# ...

# %%
# Head of _hypothesis
_hypothesis['duration']= _hypothesis['duration'].str.extract('(\d+)')
_hypothesis['duration'] = pd.to_numeric(_hypothesis['duration'])

# %%
# Another category is target_ages (4 classes).
_hypothesis['type'] = pd.Categorical(_hypothesis['type'], categories=['Movie','TV Show'])

# Head of _hypothesis
_hypothesis.head(3)
# Out:
#   show_id     type  title                                               cast  \
# 0      s1  TV Show     3%  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1      s2    Movie   7:19  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2      s3    Movie  23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
#
#      country date_added  release_year rating  duration  \
# 0     Brazil 2020-08-14          2020  TV-MA         4
# 1     Mexico 2016-12-23          2016  TV-MA        93
# 2  Singapore 2018-12-20          2011      R        78
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          description target_ages  month  \
# 0  In a future where the elite inhabit an island ...      Adults      8
# ...

# %%
# Aplying group_by duration and target_ages                 
group_by_= _hypothesis[['duration','type']].groupby(by='type')

# mean of group_by variable
group=group_by_.mean().reset_index()
group
# Out:
#       type   duration
# 0    Movie  99.330417
# 1  TV Show   1.761468

# %%
# In A and B variable grouping values 
A = group_by_.get_group('Movie')
B = group_by_.get_group('TV Show')

# mean and std. calutation for kids and older kids variables
M1 = A.mean()
S1 = A.std()

M2= B.mean()
S2 = B.std()

print('Mean for movies rated for Kids {} \n Mean for  movies rated for older kids {}'.format(M1,M2))
print('Std for  movies rated for Older Kids {} \n Std for  movies rated for kids {}'.format(S2,S1))
# Out:
# Mean for movies rated for Kids duration    99.330417
# dtype: float64
#  Mean for  movies rated for older kids duration    1.761468
# dtype: float64
# Std for  movies rated for Older Kids duration    1.561099
# dtype: float64
#  Std for  movies rated for kids duration    28.524206
# dtype: float64

# %%
# Again importing stats 
from scipy import stats

#length of groups and DOF
n1 = len(A)
n2 = len(B)
print(n1,n2)

dof = n1+n2-2
print('dof',dof)

sp_2 = ((n2-1)*S1**2  + (n1-1)*S2**2) / dof
print('SP_2 =',sp_2)

sp = np.sqrt(sp_2)
print('SP',sp)

#tvalue
t_val = (M1-M2)/(sp * np.sqrt(1/n1 + 1/n2))
print('tvalue',t_val[0])
# Out:
# 5372 2398
# dof 7768
# SP_2 = duration    252.749896
# dtype: float64
# SP duration    15.89811
# dtype: float64
# tvalue 249.88962005047787

# %%
# Checking t-distribution
stats.t.ppf(0.025,dof)
# Out:
# -1.9602694215408423

# %%
# Again t-distribution
stats.t.ppf(0.975,dof)
# Out:
# 1.9602694215408418

# %% [markdown]
# Because the t-value is not in the range, the null hypothesis is rejected.
#
# As a result, The duration which is more than 90 mins is movies.

# %%
# Printing dtypes
dataSet.dtypes
# Out:
# show_id                 object
# type                  category
# title                   object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# target_ages           category
# month                    int64
# count                    int64
# year_added               int64
# dtype: object

# %%
# Importing Natural Language Toolkit as nltk.
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Again Printing dtypes
dataSet.dtypes
# Out:
# show_id                 object
# type                  category
# title                   object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# target_ages           category
# month                    int64
# count                    int64
# year_added               int64
# dtype: object

# %%
# Printing description
dataSet['description'].astype(str)
# Out:
# 0       In a future where the elite inhabit an island ...
# 1       After a devastating earthquake hits Mexico Cit...
# 2       When an army recruit is found dead, his fellow...
# 3       In a postapocalyptic world, rag-doll robots hi...
# 4       A brilliant group of students become card-coun...
#                               ...
# 7782    When Lebanon's Civil War deprives Zozo of his ...
# 7783    A scrappy but poor boy worms his way into a ty...
# 7784    In this documentary, South African rapper Nast...
# 7785    Dessert wizard Adriano Zumbo looks for the nex...
# 7786    This documentary delves into the mystique behi...
# Name: description, Length: 7770, dtype: object

# %%
# Making a list of description feature, with the help of those features are in the list format after all the changes.
dataSet['description'] = dataSet['description'].apply(lambda x: x.split(' '))

# %%
# Converting text feature into the string from list
dataSet['description']= dataSet['description'].apply(lambda x: " ".join(x))

# making all the words in text feature to lowercase
dataSet['description']= dataSet['description'].apply(lambda x: x.lower())

# %%
# Creating a function for removing punctuation
def remove_punctuation(text):
  import string
  translator = str.maketrans('','', string.punctuation) # replacing the punctuations with no space, which in effect deletes the punctuation marks.
  return text.translate(translator) # return the text stripped of punctuation marks.

# %%
# Applying above function on text feature
dataSet['description']= dataSet['description'].apply(remove_punctuation)

# %%
# Checking description
dataSet['description'][0:10]
# Out:
# 0    in a future where the elite inhabit an island ...
# 1    after a devastating earthquake hits mexico cit...
# 2    when an army recruit is found dead his fellow ...
# 3    in a postapocalyptic world ragdoll robots hide...
# 4    a brilliant group of students become cardcount...
# 5    a genetics professor experiments with a treatm...
# 6    after an awful accident a couple admitted to a...
# 7    after one of his high school students attacks ...
# 8    when a doctor goes missing his psychiatrist wi...
# 9    an architect and his wife move into a castle t...
# Name: description, dtype: object

# %%
# Downloading stopwords from Natural Language Tool-Kit Library.
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
sw = stopwords.words('english')

# Here defining stopwords.
def stopwords(text):
  text = [word for word in text.split() if word not in sw] # Creating a function for removing the stopwords.
  return " ".join(text) # Joining the list of words with space separator.
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Applying above function on text feature.
dataSet['description']=dataSet['description'].apply(stopwords)

# %%
# This is how the value looks like after removing the stepwords.
dataSet['description'][0]
# Out:
# 'future elite inhabit island paradise far crowded slums get one chance join 3 saved squalor'

# %%
# Importing TfidVectorizer from sklearn library
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Applying Tfidf Vectorizer.
tfidfmodel = TfidfVectorizer(max_features=5000)
X_tfidf = tfidfmodel.fit_transform(dataSet['description'])
X_tfidf.shape
# Out:
# (7770, 5000)

# %%
# Here we are converting X into array form for clustering
X = X_tfidf.toarray()

# %%
# Finding optimal number of clusters using the elbow method. 
from sklearn.cluster import KMeans  
wcss_list= []  #Initializing the list for the values of WCSS  
  
# Using for loop for iterations from 1 to 30.  
for i in range(1, 30):  
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state= 42)  
    kmeans.fit(X)  
    wcss_list.append(kmeans.inertia_)  
plt.plot(range(1, 30), wcss_list)  
plt.title('The Elobw Method Graph')  
plt.xlabel('Number of clusters(k)')  
plt.ylabel('wcss_list')  
plt.show()

# %%
# Importing sillhoute score
from sklearn.metrics import silhouette_score

# %%
# Sillhoute score of clusters
sill = []
for i in range (2, 30):
  model = KMeans(n_clusters=i,init ='k-means++',random_state=51)
  model.fit(X)
  y1 = model.predict(X)
  score = silhouette_score(X,y1)
  sill.append(score)
  print('cluster: %d \t Sillhoute: %0.4f'%(i,score))
# Out:
# cluster: 2 	 Sillhoute: 0.0014
# cluster: 3 	 Sillhoute: 0.0018
# cluster: 4 	 Sillhoute: 0.0023
# cluster: 5 	 Sillhoute: 0.0025
# cluster: 6 	 Sillhoute: 0.0034
# cluster: 7 	 Sillhoute: 0.0036
# cluster: 8 	 Sillhoute: 0.0040
# cluster: 9 	 Sillhoute: 0.0042
# cluster: 10 	 Sillhoute: 0.0047

# %%
# Plotting Sillhoute's score
plt.plot(sill,'bs--')
plt.xticks(list(range(0,30)),list(range(2,30)))
plt.grid(),plt.xlabel('Number of cluster')
plt.show()

# %%
# Dataset Traning for K-means model
kmeans = KMeans(n_clusters=26, init='k-means++', random_state= 42)
y_predict = kmeans.fit_predict(X)

# %%
# Predicting the Clusters & Evaluate the Sillhoute Score
score = silhouette_score(X, y_predict)
print("The Silhouette score is {}".format(score))

# %%
# Adding a seperate column for Cluster
dataSet["cluster"] = y_predict

# %%
# Checking value count
dataSet["cluster"].value_counts()

# %%
# Applying Plots
fig, ax = plt.subplots(figsize=(15,6))
sns.countplot(x='cluster', hue='type', lw=5, color='violet', data=dataSet, ax=ax)

# %%
# Applying Scatter Plot For Clusters
fig = px.scatter(dataSet, y="description", x="cluster", color="cluster")
fig.update_traces(marker_size=100)
fig.show()

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize =(8, 8))
plt.title('Visualising The Data')
Dendrogram = shc.dendrogram((shc.linkage(X, method ='ward')))

# %%
# Fitting our variable in Agglomerative Clusters.

from sklearn.cluster import AgglomerativeClustering # Importing Agglomerative Clusters.
aggh = AgglomerativeClustering(n_clusters=6, affinity='euclidean', linkage='ward')  
aggh.fit(X)

# Predicting by using our Model
y_hc=aggh.fit_predict(X)

# %%
# Creating a column where each row is assigned to their separate clusters
_hierarchical = dataSet.copy()
_hierarchical['cluster'] = aggh.labels_
_hierarchical.head()

# %%
# Checking the number of points are present in each clusters by using ploting.
plt.bar([x for x in range(6)], _hierarchical.groupby(['cluster'])['description'].count(), alpha = 0.4)
plt.title('KMeans Cluster Points')
plt.xlabel('Cluster Number')
plt.ylabel('Numbers of Points')
plt.show()

# %%
# Now Cheking Silhouette Coefficient.
print("Silhouette Coefficient: %0.3f"%silhouette_score(X, aggh.labels_, metric='euclidean'))

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
